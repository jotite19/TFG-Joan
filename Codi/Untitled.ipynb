# %%
pip freeze
# Out:
# argon2-cffi==21.1.0
# ase==3.22.1
# attrs==21.2.0
# backcall==0.2.0
# bleach==4.1.0
# certifi==2021.10.8
# cffi==1.15.0
# charset-normalizer==2.0.9
# cloudpickle==2.2.1
# cmake==3.25.2
# colorama==0.4.4
# cycler==0.10.0
# Cython==0.29.28
# debugpy==1.5.1
# decorator==5.1.0
# defusedxml==0.7.1
# entrypoints==0.3
# gym==0.26.2
# gym-notices==0.0.8
# idna==3.3
# ipykernel==6.4.2
# ipython==7.28.0
# ipython-genutils==0.2.0
# ipywidgets==7.6.5
# jedi==0.18.0
# Jinja2==3.0.2
# joblib==1.1.0
# jsonschema==4.1.2
# jupyter==1.0.0
# jupyter-client==7.0.6
# jupyter-console==6.4.0
# jupyter-core==4.8.1
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==1.0.2
# kiwisolver==1.3.2
# MarkupSafe==2.0.1
# matplotlib==3.4.3
# matplotlib-inline==0.1.3
# mistune==0.8.4
# mpmath==1.2.1
# nbclient==0.5.4
# nbconvert==6.2.0
# nbformat==5.1.3
# nes-py==8.2.1
# nest-asyncio==1.5.1
# notebook==6.4.5
# numpy==1.22.3
# opencv-python==4.5.5.64
# packaging==21.0
# pandas==1.3.5
# pandocfilters==1.5.0
# ...

# %%
pip install matscipy==0.7.0
# Out:
# ...
#   Using cached matscipy-0.7.0.tar.gz (255 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for matscipy
# Failed to build matscipy
# ...
#   Running setup.py install for matscipy: started
#   Running setup.py install for matscipy: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [242 lines of output]
#   C:\Users\Joan\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\dist.py:788: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#     warnings.warn(
# ...

# %%
pip install schnetpack --no-cache-dir
# Out:
# ...
#      -------------------------------------- 224.6/224.6 kB 4.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 518.6/518.6 kB 5.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.6/2.6 MB 5.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 154.5/154.5 kB 4.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 239.0/239.0 kB 7.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 255.1/255.1 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 826.4/826.4 kB 5.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 79.5/79.5 kB 4.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 117.0/117.0 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
# ...
